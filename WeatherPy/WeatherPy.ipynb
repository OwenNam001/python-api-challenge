# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# << My Work >>
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 601

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 634

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# << My Work >>
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "appid=" + weather_api_key + "&units=" + units + "&q=" + city  

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        
        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 2 of Set 1 | mili
# Processing Record 3 of Set 1 | weno
# Processing Record 4 of Set 1 | isafjordur
# Processing Record 5 of Set 1 | bethel
# Processing Record 6 of Set 1 | west island
# Processing Record 7 of Set 1 | puerto ayora
# Processing Record 8 of Set 1 | little cayman
# City not found. Skipping...
# Processing Record 9 of Set 1 | salinas
# Processing Record 10 of Set 1 | waitangi
# Processing Record 11 of Set 1 | la sarre
# Processing Record 12 of Set 1 | wanning
# Processing Record 13 of Set 1 | port mathurin
# Processing Record 14 of Set 1 | adamstown
# Processing Record 15 of Set 1 | tolanaro
# Processing Record 16 of Set 1 | posto fiscal rolim de moura
# Processing Record 17 of Set 1 | haiku-pauwela
# Processing Record 18 of Set 1 | rawson
# Processing Record 19 of Set 1 | georgetown
# ...

# %%
# Set the API base URL
url = # YOUR CODE HERE

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = # YOUR CODE HERE
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = # YOUR CODE HERE

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = # YOUR CODE HERE
        city_lng = # YOUR CODE HERE
        city_max_temp = # YOUR CODE HERE
        city_humidity = # YOUR CODE HERE
        city_clouds = # YOUR CODE HERE
        city_wind = # YOUR CODE HERE
        city_country = # YOUR CODE HERE
        city_date = # YOUR CODE HERE

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | faya
# Processing Record 2 of Set 1 | farsund
# Processing Record 3 of Set 1 | new norfolk
# Processing Record 4 of Set 1 | jamestown
# Processing Record 5 of Set 1 | lanzhou
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | albany
# Processing Record 8 of Set 1 | carnarvon
# Processing Record 9 of Set 1 | sisimiut
# Processing Record 10 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 11 of Set 1 | saint-pierre
# Processing Record 12 of Set 1 | colorado
# Processing Record 13 of Set 1 | nikolskoye
# Processing Record 14 of Set 1 | trairi
# Processing Record 15 of Set 1 | dobryanka
# Processing Record 16 of Set 1 | qaanaaq
# Processing Record 17 of Set 1 | mataura
# Processing Record 18 of Set 1 | khatanga
# Processing Record 19 of Set 1 | tasiilaq
# Processing Record 20 of Set 1 | tiksi
# Processing Record 21 of Set 1 | puerto ayora
# ...

# %%
# << My Work >>
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          607
# Lat           607
# Lng           607
# Max Temp      607
# Humidity      607
# Cloudiness    607
# Wind Speed    607
# Country       607
# Date          607
# dtype: int64

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = # YOUR CODE HERE

# Show Record Count
city_data_df.count()
# Out:
# City          577
# Lat           577
# Lng           577
# Max Temp      577
# Humidity      577
# Cloudiness    577
# Wind Speed    577
# Country       577
# Date          577
# dtype: int64

# %%
# << My Work >>
# Display sample data
city_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0         mili   6.0815  171.7350     28.32        82         100        7.46
# 1         weno   7.4515  151.8468     30.97        79         100        3.60
# 2   isafjordur  66.0755  -23.1240      5.39        82          61        0.56
# 3       bethel  41.3712  -73.4140     12.65        45           0        4.12
# 4  west island -12.1568   96.8225     27.99        83          75        6.69
#
#   Country        Date
# 0      MH  1713914445
# 1      FM  1713914122
# 2      IS  1713914135
# 3      US  1713914140
# 4      CC  1713914182

# %%
# Display sample data
city_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0         faya  18.3851   42.4509     22.06        35          21        2.60
# 1      farsund  58.0948    6.8047     13.30       100           0        7.65
# 2  new norfolk -42.7826  147.0587     11.72        58          12        1.34
# 3    jamestown  42.0970  -79.2353      5.77        77         100        9.77
# 4      lanzhou  36.0564  103.7922     14.53        48          59        1.20
#
#   Country        Date
# 0      SA  1666108228
# 1      NO  1666108228
# 2      AU  1666108230
# 3      US  1666107934
# 4      CN  1666108230

# %%
# << My Work >>
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# << My Work >>
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0               mili   6.0815  171.7350     28.32        82         100
# 1               weno   7.4515  151.8468     30.97        79         100
# 2         isafjordur  66.0755  -23.1240      5.39        82          61
# 3             bethel  41.3712  -73.4140     12.65        45           0
# 4        west island -12.1568   96.8225     27.99        83          75
#
#          Wind Speed Country        Date
# City_ID
# 0              7.46      MH  1713914445
# 1              3.60      FM  1713914122
# 2              0.56      IS  1713914135
# 3              4.12      US  1713914140
# 4              6.69      CC  1713914182

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0               faya  18.3851   42.4509     22.06        35          21
# 1            farsund  58.0948    6.8047     13.30       100           0
# 2        new norfolk -42.7826  147.0587     11.72        58          12
# 3          jamestown  42.0970  -79.2353      5.77        77         100
# 4            lanzhou  36.0564  103.7922     14.53        48          59
#
#          Wind Speed Country        Date
# City_ID
# 0              2.60      SA  1666108228
# 1              7.65      NO  1666108228
# 2              1.34      AU  1666108230
# 3              9.77      US  1666107934
# 4              1.20      CN  1666108230

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# << My Work >>
# Build scatter plot for latitude vs. temperature
x_values = city_data_df['Lat']
y_values = city_data_df['Max Temp']
plt.scatter(x_values,y_values, marker='o', alpha=0.8, edgecolors='black')

# Incorporate the other graph properties
plt.title('City Max Latitude vs. Temperature (2024-04-23)')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')
plt.grid()

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %%
# Build scatter plot for latitude vs. temperature
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# << My Work >>
# Build scatter plot for latitude vs. temperature
x_values = city_data_df['Lat']
y_values = city_data_df['Humidity']
plt.scatter(x_values,y_values, marker='o', alpha=0.8, edgecolors='black')

# Incorporate the other graph properties
plt.title('City Latitude vs. Humidity (2024-04-23)')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid()

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# << My Work >>
# Build scatter plot for latitude vs. temperature
x_values = city_data_df['Lat']
y_values = city_data_df['Cloudiness']
plt.scatter(x_values,y_values, marker='o', alpha=0.8, edgecolors='black')

# Incorporate the other graph properties
plt.title('City Latitude vs. Cloudiness (2024-04-23)')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid()

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# << My Work >>
# Build scatter plot for latitude vs. temperature
x_values = city_data_df['Lat']
y_values = city_data_df['Wind Speed']
plt.scatter(x_values,y_values, marker='o', alpha=0.8, edgecolors='black')

# Incorporate the other graph properties
plt.title('City Latitude vs. Wind Speed (2024-04-23)')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.grid()

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE

# %%
# << My Work >>
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[(city_data_df["Lat"] >= 0)]

# Display sample data
northern_hemi_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0              mili   6.0815  171.7350     28.32        82         100
# 1              weno   7.4515  151.8468     30.97        79         100
# 2        isafjordur  66.0755  -23.1240      5.39        82          61
# 3            bethel  41.3712  -73.4140     12.65        45           0
# 6           salinas  36.6777 -121.6555     19.99        58          20
#
#          Wind Speed Country        Date
# City_ID
# 0              7.46      MH  1713914445
# 1              3.60      FM  1713914122
# 2              0.56      IS  1713914135
# 3              4.12      US  1713914140
# 6              7.72      US  1713914447

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE

# Display sample data
northern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             faya  18.3851   42.4509     22.06        35          21
# 1          farsund  58.0948    6.8047     13.30       100           0
# 3        jamestown  42.0970  -79.2353      5.77        77         100
# 4          lanzhou  36.0564  103.7922     14.53        48          59
# 6           albany  42.6001  -73.9662     10.36        74          29
#
#          Wind Speed Country        Date
# City_ID
# 0              2.60      SA  1666108228
# 1              7.65      NO  1666108228
# 3              9.77      US  1666107934
# 4              1.20      CN  1666108230
# 6              2.10      US  1666108231

# %%
# << My Work >>
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[(city_data_df["Lat"] < 0)]

# Display sample data
southern_hemi_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 4          west island -12.1568   96.8225     27.99        83          75
# 5         puerto ayora  -0.7393  -90.3518     25.86        93          99
# 7             waitangi -43.9535 -176.5597     15.46        85          78
# 10       port mathurin -19.6833   63.4167     26.98        76          25
# 11           adamstown -25.0660 -130.1015     23.00        85         100
#
#          Wind Speed Country        Date
# City_ID
# 4              6.69      CC  1713914182
# 5              0.89      EC  1713914130
# 7              4.92      NZ  1713914137
# 10             6.99      MU  1713914182
# 11             8.87      PN  1713914047

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE

# Display sample data
southern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2         new norfolk -42.7826  147.0587     11.72        58          12
# 5             ushuaia -54.8000  -68.3000      8.81        81          75
# 7           carnarvon -24.8667  113.6333     20.02        76           0
# 9        saint-pierre -21.3393   55.4781     22.82        68           0
# 10           colorado -22.8375  -51.9731     20.36        86          96
#
#          Wind Speed Country        Date
# City_ID
# 2              1.34      AU  1666108230
# 5              3.09      AR  1666108231
# 7              7.46      AU  1666108232
# 9              5.14      RE  1666108236
# 10             4.69      BR  1666107965

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# << My Work >>
# Linear regression on Northern Hemisphere
# Add the linear regression equation and line to plot
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

plt.annotate(line_eq,(5, -10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
print(f"The r-squared is: {rvalue**2}")

# Save the figure
plt.savefig("output_data/Fig5.png")

plt.show()
# Out:
# The r-squared is: 0.7425672965324045

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.7161472181434118

# %%
# << My Work >>
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

plt.annotate(line_eq,(-55, 30),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
print(f"The r-squared is: {rvalue**2}")

# Save the figure
plt.savefig("output_data/Fig6.png")

plt.show()
# Out:
# The r-squared is: 0.5956037075914554

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.4121057168607245

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %%
# << My Work >>
import scipy.stats as st

x_values_northern = northern_hemi_df['Lat']
y_values_northern = northern_hemi_df['Max Temp']

x_values_southern = southern_hemi_df['Lat']
y_values_southern = southern_hemi_df['Max Temp']

correlation_northern = st.pearsonr(x_values_northern,y_values_northern)
correlation_southern = st.pearsonr(x_values_southern,y_values_southern)

print(f"The correlation between Northern hemi. Lat vs Max Temp is {abs(round(correlation_northern[0],2))}")
print(f"The correlation between Southern hemi. Lat vs Max Temp is {abs(round(correlation_southern[0],2))}")

# Northern hemisphere has absolute value of 0.86 and Southern hemisphere has absolute value of 0.77
# for Pearson's Correlation, which means latitude and Max temperature has Strong correlation, as it values
# are over 0.7 based on Pearson's Correlation
# And also, I noticed that overall Max temperature for 2024 has increased a bit rather than 2022
# Out:
# The correlation between Northern hemi. Lat vs Max Temp is 0.86
# The correlation between Southern hemi. Lat vs Max Temp is 0.77

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# << My Work >>
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

plt.annotate(line_eq,(45, 10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
print(f"The r-squared is: {rvalue**2}")

# Save the figure
plt.savefig("output_data/Fig7.png")

plt.show()
# Out:
# The r-squared is: 0.02930860234461498

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.05689741545789598

# %%
# << My Work >>
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

plt.annotate(line_eq,(-55, 22),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
print(f"The r-squared is: {rvalue**2}")

# Save the figure
plt.savefig("output_data/Fig8.png")

plt.show()
# Out:
# The r-squared is: 0.11996763709525511

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.0002808747046324607

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %%
# << My Work >>
import scipy.stats as st

x_values_northern = northern_hemi_df['Lat']
y_values_northern = northern_hemi_df['Humidity']

x_values_southern = southern_hemi_df['Lat']
y_values_southern = southern_hemi_df['Humidity']

correlation_northern = st.pearsonr(x_values_northern,y_values_northern)
correlation_southern = st.pearsonr(x_values_southern,y_values_southern)

print(f"The correlation between Northern hemi. Lat vs Humidity is {abs(round(correlation_northern[0],2))}")
print(f"The correlation between Southern hemi. Lat vs Humidity is {abs(round(correlation_southern[0],2))}")

# Northern hemisphere has absolute value of 0.17 and Southern hemisphere has absolute value of 0.35
# for Pearson's Correlation, which means latitude and Humidity has None or very weak correlation, as it values
# are less than or just around 0.3 based on Pearson's Correlation
# And also, I noticed that overall Humidity values for 2024 are more densely packed and more various values rather than 2022
# Out:
# The correlation between Northern hemi. Lat vs Humidity is 0.17
# The correlation between Southern hemi. Lat vs Humidity is 0.35

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# << My Work >>
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

plt.annotate(line_eq,(40, 25),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
print(f"The r-squared is: {rvalue**2}")

# Save the figure
plt.savefig("output_data/Fig9.png")

plt.show()
# Out:
# The r-squared is: 0.004051560891714165

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.024026517125811015

# %%
# << My Work >>
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

plt.annotate(line_eq,(-20, 20),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
print(f"The r-squared is: {rvalue**2}")

# Save the figure
plt.savefig("output_data/Fig10.png")

plt.show()
# Out:
# The r-squared is: 0.017622301266735686

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.02056735429994368

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %%
# << My Work >>
import scipy.stats as st

x_values_northern = northern_hemi_df['Lat']
y_values_northern = northern_hemi_df['Cloudiness']

x_values_southern = southern_hemi_df['Lat']
y_values_southern = southern_hemi_df['Cloudiness']

correlation_northern = st.pearsonr(x_values_northern,y_values_northern)
correlation_southern = st.pearsonr(x_values_southern,y_values_southern)

print(f"The correlation between Northern hemi. Lat vs Cloudiness is {abs(round(correlation_northern[0],2))}")
print(f"The correlation between Southern hemi. Lat vs Cloudiness is {abs(round(correlation_southern[0],2))}")

# Northern hemisphere has absolute value of 0.06 and Southern hemisphere has absolute value of 0.13
# for Pearson's Correlation, which means latitude and Cloudiness has None or very weak correlation, as it values
# are less than 0.3 based on Pearson's Correlation
# And also, I noticed that the latitude with 0% cloudiness has increased in 2024 compared to 2022
# Out:
# The correlation between Northern hemi. Lat vs Cloudiness is 0.06
# The correlation between Southern hemi. Lat vs Cloudiness is 0.13

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# << My Work >>
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

plt.annotate(line_eq,(1, 11),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
print(f"The r-squared is: {rvalue**2}")

# Save the figure
plt.savefig("output_data/Fig11.png")

plt.show()
# Out:
# The r-squared is: 0.003988615437617583

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.030396762354449467

# %%
# << My Work >>
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

plt.annotate(line_eq,(-50, 10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
print(f"The r-squared is: {rvalue**2}")

# Save the figure
plt.savefig("output_data/Fig12.png")

plt.show()
# Out:
# The r-squared is: 0.06185988266205264

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.062239040700515696

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %%
# << My Work >>
import scipy.stats as st

x_values_northern = northern_hemi_df['Lat']
y_values_northern = northern_hemi_df['Wind Speed']

x_values_southern = southern_hemi_df['Lat']
y_values_southern = southern_hemi_df['Wind Speed']

correlation_northern = st.pearsonr(x_values_northern,y_values_northern)
correlation_southern = st.pearsonr(x_values_southern,y_values_southern)

print(f"The correlation between Northern hemi. Lat vs Wind Speed is {abs(round(correlation_northern[0],2))}")
print(f"The correlation between Southern hemi. Lat vs Wind Speed is {abs(round(correlation_southern[0],2))}")

# Northern hemisphere has absolute value of 0.06 and Southern hemisphere has absolute value of 0.25
# for Pearson's Correlation, which means latitude and Wind Speed has None or very weak correlation, as it values
# are less than 0.3 based on Pearson's Correlation
# Out:
# The correlation between Northern hemi. Lat vs Wind Speed is 0.06
# The correlation between Southern hemi. Lat vs Wind Speed is 0.25
